# %% [markdown]
# ### การวิเคราะห์ ยอด Deleivery หรือ Orders ตามช่วงวัย ปี2023

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("../data/clean/clean_data.csv")

# %% [markdown]
# #### 1 . สินค้าที่ถูก จัดส่ง ที่มากที่สุด แต่ละช่วงวัย ของ Data set

# %%
top_age_per_product_delivered = (
    df[(df["Year"] == 2023) & (df["Delivered"] == True)]
    .groupby(["Product Name", "AgeGroup"])["Quantity"]
    .sum()
)

top_age_per_product_delivered = top_age_per_product_delivered.loc[
    top_age_per_product_delivered.groupby(level=0).idxmax()
]

# %%
print(top_age_per_product_delivered.sort_values(ascending=False))
# Out:
# Product Name  AgeGroup
# Smartphone    50-59       38
# Monitor       60+         35
# Laptop        60+         35
# Smartwatch    50-59       32
# Keyboard      40-49       32
# Mouse         60+         30
# Headphones    20-29       29
# Name: Quantity, dtype: int64

# %% [markdown]
# #### 2 . สินค้าที่ถูก สั่ง ที่มากที่สุด แต่ละช่วงวัย ของ Data set

# %%
top_age_per_product_orders = (
    df[df["Year"] == 2023]
    .groupby(["Product Name", "AgeGroup"])["Quantity"]
    .sum()
)

top_age_per_product_orders = top_age_per_product_orders.loc[
    top_age_per_product_orders.groupby(level=0).idxmax()
]

# %%
print(top_age_per_product_orders.sort_values(ascending=False))
# Out:
# Product Name  AgeGroup
# Smartphone    50-59       125
# Monitor       50-59       111
# Smartwatch    50-59       100
# Laptop        60+          98
# Keyboard      60+          88
# Headphones    50-59        80
# Mouse         50-59        80
# Name: Quantity, dtype: int64

# %% [markdown]
# #### 3 . วัดแต่ละช่วงวัย ว่า สนใจสินค้า ใด บ้าง ตาม ความมากน้อย Visualisation

# %% [markdown]
# ###### *วัดจาก จํานวน orders　แทนความสนใจ ข้อมูล ปี 2023

# %% [markdown]
# ##### ความสนใจ สินค้า ใน วัย ตํ่ากว่า 20 ปี

# %%
labels = ["<20","20-29","30-39","40-49","50-59","60+"]

# %%
Interest_trend_AgeGroup_under20 = (
    df[(df["Year"] == 2023) & (df["AgeGroup"] == "<20")]
    .groupby("Product Name")["Quantity"]
    .sum()
    .sort_values(ascending=False)
)

# %%
plt.bar(Interest_trend_AgeGroup_under20.index, Interest_trend_AgeGroup_under20.values)
plt.xlabel("Age Group")
plt.ylabel("Total Quantity")
plt.title("Total Quantity of Delivered Products for Age Group <20 in 2023")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### ความสนใจ สินค้า ใน วัย ตํ่ากว่า 20-29 ปี

# %%
Interest_trend_AgeGroup_20to29 = (
    df[(df["Year"] == 2023) & (df["AgeGroup"] == "20-29")]
    .groupby("Product Name")["Quantity"]
    .sum()
    .sort_values(ascending=False)
)

# %%
plt.bar(Interest_trend_AgeGroup_20to29.index, Interest_trend_AgeGroup_20to29.values)
plt.xlabel("Product Name")
plt.ylabel("Total Quantity")
plt.title("Total Quantity of Delivered Products for Age Group 20-29 in 2023")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### ความสนใจ สินค้า ใน วัย ตํ่ากว่า 30-39 ปี

# %%
Interest_trend_AgeGroup_30to39 = (
    df[(df["Year"] == 2023) & (df["AgeGroup"] == "30-39")]
    .groupby("Product Name")["Quantity"]
    .sum()
    .sort_values(ascending=False)
)

# %%
plt.bar(Interest_trend_AgeGroup_30to39.index, Interest_trend_AgeGroup_30to39.values)
plt.xlabel("Product Name")
plt.ylabel("Total Quantity")
plt.title("Total Quantity of Delivered Products for Age Group 30-39 in 2023")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### ความสนใจ สินค้า ใน วัย ตํ่ากว่า 40-49 ปี

# %%
Interest_trend_AgeGroup_40to49 = (
    df[(df["Year"] == 2023) & (df["AgeGroup"] == "40-49")]
    .groupby("Product Name")["Quantity"]
    .sum()
    .sort_values(ascending=False)
)

# %%
plt.bar(Interest_trend_AgeGroup_40to49.index, Interest_trend_AgeGroup_40to49.values)
plt.xlabel("Product Name")
plt.ylabel("Total Quantity")
plt.title("Total Quantity of Delivered Products for Age Group 40-49 in 2023")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### ความสนใจ สินค้า ใน วัย ตํ่ากว่า 50-59 ปี

# %%
Interest_trend_AgeGroup_50to59 = (
    df[(df["Year"] == 2023) & (df["AgeGroup"] == "50-59")]
    .groupby("Product Name")["Quantity"]
    .sum()
    .sort_values(ascending=False)
)

# %%
plt.bar(Interest_trend_AgeGroup_50to59.index, Interest_trend_AgeGroup_50to59.values)
plt.xlabel("Product Name")
plt.ylabel("Total Quantity")
plt.title("Total Quantity of Delivered Products for Age Group 50-59 in 2023")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### ความสนใจ สินค้า ใน วัย ตํ่ากว่า 60+ ปี

# %%
Interest_trend_AgeGroup_60plus = (
    df[(df["Year"] == 2023) & (df["AgeGroup"] == "60+")]
    .groupby("Product Name")["Quantity"]
    .sum()
    .sort_values(ascending=False)
)

# %%
plt.bar(Interest_trend_AgeGroup_60plus.index, Interest_trend_AgeGroup_60plus.values)
plt.xlabel("Product Name")
plt.ylabel("Total Quantity")
plt.title("Total Quantity of Delivered Products for Age Group 60+ in 2023")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### สรุป ความสนใจ สินค้า ในแต่ละวัย

# %%
product_orders = (
    df[df["Year"] == 2023]
    .groupby(["Product Name", "AgeGroup"])["Quantity"]
    .mean()
    .unstack()
)

print(product_orders)
# Out:
# AgeGroup         20-29     30-39     40-49     50-59       60+       <20
# Product Name
# Headphones    2.947368  3.466667  2.904762  3.333333  2.956522  2.666667
# Keyboard      3.047619  3.666667  2.857143  3.150000  3.034483  3.200000
# Laptop        3.111111  2.631579  3.260870  3.100000  2.648649  3.000000
# Monitor       3.100000  2.500000  2.555556  2.846154  2.705882  2.800000
# Mouse         2.631579  3.235294  3.235294  2.857143  2.678571  2.625000
# Smartphone    2.692308  2.800000  2.956522  3.205128  3.290323  3.750000
# Smartwatch    2.941176  2.736842  2.842105  3.448276  3.333333  3.500000

# %% [markdown]
# ##### สรุป จํานวนจัดส่ง สินค้า ในแต่ละวัย

# %%
product_delieveried = (
    df[(df["Year"] == 2023) & (df["Delivered"] == True)]
    .groupby(["Product Name", "AgeGroup"])["Quantity"]
    .mean()
    .unstack()
)

print(product_delieveried)
# Out:
# AgeGroup         20-29     30-39     40-49     50-59       60+  <20
# Product Name
# Headphones    2.900000  3.400000  3.571429  2.714286  3.200000  1.0
# Keyboard      3.375000  3.111111  2.666667  2.000000  2.909091  4.0
# Laptop        3.500000  2.750000  2.875000  2.444444  2.916667  3.0
# Monitor       3.285714  2.272727  2.111111  2.538462  2.916667  3.5
# Mouse         2.666667  3.125000  3.166667  3.166667  3.000000  1.0
# Smartphone    4.000000  4.000000  2.000000  3.800000  2.777778  4.5
# Smartwatch    3.333333  2.714286  3.000000  3.555556  3.000000  4.0
